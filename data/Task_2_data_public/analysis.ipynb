# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data_0=json.load(open('intervention_'+str(0)+'.json','r',encoding="utf-8"))
data_2=json.load(open('intervention_'+str(2)+'.json','r',encoding="utf-8"))

# %%
import matplotlib.pyplot as plt
X=np.array(data_0[9]['conditioning'])
fig = plt.figure(figsize=[15, 15*0.618], dpi=300)

plt.imshow(X[:,1:], cmap=plt.cm.coolwarm, vmin=0, vmax=1)
plt.colorbar()
plt.xlim=(0, 50)
plt.xticks=np.arange(0, 50, 1)
plt.show()

print(X[:,0])
# Out:
# [46. 40. 21. 34. 22. 19.  8. 14.  3.  9. 39. 40.  6. 39. 32. 14. 21.  0.
#  23. 16.  4.  1. 43. 12. 18. 48. 20.  3. 24. 24. 28. 15. 27. 41.  7.  5.
#  29. 29.  1. 43. 27.  7. 31. 26. 35. 45. 48. 35. 32. 30.  5. 16.  8. 48.
#  46. 22. 43. 16. 15.  8.  4. 23. 33. 49. 21. 46. 43. 45. 28. 29. 16. 39.
#  30. 14. 28. 20. 25.  5. 35. 39. 27.  9. 38. 37. 26. 37. 21.  2.  9.  6.
#  32.  7. 40. 24. 43. 13. 43. 40. 42.  8. 33. 17.  6. 25.  0.  7. 12. 46.
#  13.  4. 28.  3. 43. 42. 12. 36. 19. 39. 11. 26.  3.]
